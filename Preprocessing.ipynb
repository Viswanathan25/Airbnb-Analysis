# %% [markdown]
# <a href="https://colab.research.google.com/github/Viswanathan25/Airbnb-Analysis/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preprocessing

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snb
from sklearn import preprocessing

# %%
#Collecting the datasets
df1 = pd.read_csv("/content/drive/MyDrive/Singapore datasets/singapore land sales/ResaleFlatPricesBasedonApprovalDate19901999.csv")
df2 = pd.read_csv("/content/drive/MyDrive/Singapore datasets/singapore land sales/ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df3 = pd.read_csv("/content/drive/MyDrive/Singapore datasets/singapore land sales/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df4 = pd.read_csv("/content/drive/MyDrive/Singapore datasets/singapore land sales/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df5 = pd.read_csv("/content/ResaleflatpricesbasedonregistrationdatefromJan2017onwards-1.csv")

# %%
#checking the data shapes
df = [df1,df2,df3,df4,df5]
for i in df:
  print(i.shape)
# Out:
# (287196, 10)
# (369651, 10)
# (52203, 10)
# (37153, 11)
# (175359, 11)

# %% [markdown]
# Merging the 5 Dataframes

# %%
#concating the all data frames into a single data frame
df = pd.concat([df1,df2,df3,df4,df5],ignore_index=True)

# %% [markdown]
# Displaying the dataFrames

# %%
#Viewing head data
df.head(10)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# 5  1990-01  ANG MO KIO    3 ROOM   211  ANG MO KIO AVE 3     01 TO 03
# 6  1990-01  ANG MO KIO    3 ROOM   202  ANG MO KIO AVE 3     07 TO 09
# 7  1990-01  ANG MO KIO    3 ROOM   235  ANG MO KIO AVE 3     10 TO 12
# 8  1990-01  ANG MO KIO    3 ROOM   235  ANG MO KIO AVE 3     04 TO 06
# 9  1990-01  ANG MO KIO    3 ROOM   232  ANG MO KIO AVE 3     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
# 5            67.0  NEW GENERATION                 1977       46000.0
# 6            67.0  NEW GENERATION                 1977       42000.0
# 7            67.0  NEW GENERATION                 1977       38000.0
# 8            67.0  NEW GENERATION                 1977       40000.0
# 9            67.0  NEW GENERATION                 1977       47000.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN

# %%
#Displaying tail data
df.tail(10)
# Out:
#           month    town         flat_type block     street_name storey_range  \
# 919268  2024-02  YISHUN            5 ROOM  512C    YISHUN ST 51     10 TO 12
# 919269  2024-02  YISHUN            5 ROOM  502B    YISHUN ST 51     10 TO 12
# 919270  2024-02  YISHUN            5 ROOM  513A    YISHUN ST 51     01 TO 03
# 919271  2024-02  YISHUN            5 ROOM   758    YISHUN ST 72     10 TO 12
# 919272  2024-02  YISHUN         EXECUTIVE   405    YISHUN AVE 6     04 TO 06
# 919273  2024-02  YISHUN         EXECUTIVE   325     YISHUN CTRL     04 TO 06
# 919274  2024-02  YISHUN         EXECUTIVE   387  YISHUN RING RD     04 TO 06
# 919275  2024-02  YISHUN         EXECUTIVE   606    YISHUN ST 61     10 TO 12
# 919276  2024-02  YISHUN         EXECUTIVE   824    YISHUN ST 81     07 TO 09
# 919277  2024-02  YISHUN  MULTI-GENERATION   666    YISHUN AVE 4     04 TO 06
#
#         floor_area_sqm        flat_model  lease_commence_date  resale_price  \
# 919268           113.0          Improved                 2017      750000.0
# 919269           112.0          Improved                 2018      718000.0
# 919270           113.0          Improved                 2018      600888.0
# 919271           122.0          Improved                 1986      700000.0
# 919272           142.0         Apartment                 1988      780000.0
# 919273           146.0        Maisonette                 1988      860000.0
# 919274           142.0         Apartment                 1988      820000.0
# 919275           142.0         Apartment                 1987      795000.0
# 919276           146.0        Maisonette                 1987      935000.0
# 919277           164.0  Multi Generation                 1987      998000.0
#
#            remaining_lease
# 919268  92 years 07 months
# 919269            93 years
# 919270   93 years 01 month
# 919271  61 years 10 months
# 919272  63 years 07 months
# 919273  63 years 10 months
# 919274  63 years 05 months
# 919275  62 years 11 months
# 919276  62 years 10 months
# 919277  62 years 11 months

# %%
#Checking data shape and info
df.shape
# Out:
# (919278, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919278 entries, 0 to 919277
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                919278 non-null  object
#  1   town                 919278 non-null  object
#  2   flat_type            919278 non-null  object
#  3   block                919278 non-null  object
#  4   street_name          919278 non-null  object
#  5   storey_range         919278 non-null  object
#  6   floor_area_sqm       919278 non-null  float64
#  7   flat_model           919278 non-null  object
#  8   lease_commence_date  919278 non-null  int64
#  9   resale_price         919278 non-null  float64
#  10  remaining_lease      210228 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.1+ MB

# %% [markdown]
# Checking missing values

# %%
#displaying Null values
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
#Droping the column
df = df.drop(columns ='remaining_lease')
df
# Out:
#           month        town         flat_type block       street_name  \
# 0       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 1       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 2       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 3       1990-01  ANG MO KIO            1 ROOM   309  ANG MO KIO AVE 1
# 4       1990-01  ANG MO KIO            3 ROOM   216  ANG MO KIO AVE 1
# ...         ...         ...               ...   ...               ...
# 919273  2024-02      YISHUN         EXECUTIVE   325       YISHUN CTRL
# 919274  2024-02      YISHUN         EXECUTIVE   387    YISHUN RING RD
# 919275  2024-02      YISHUN         EXECUTIVE   606      YISHUN ST 61
# 919276  2024-02      YISHUN         EXECUTIVE   824      YISHUN ST 81
# 919277  2024-02      YISHUN  MULTI-GENERATION   666      YISHUN AVE 4
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          10 TO 12            31.0          IMPROVED                 1977
# 1          04 TO 06            31.0          IMPROVED                 1977
# 2          10 TO 12            31.0          IMPROVED                 1977
# 3          07 TO 09            31.0          IMPROVED                 1977
# 4          04 TO 06            73.0    NEW GENERATION                 1976
# ...             ...             ...               ...                  ...
# 919273     04 TO 06           146.0        Maisonette                 1988
# 919274     04 TO 06           142.0         Apartment                 1988
# 919275     10 TO 12           142.0         Apartment                 1987
# 919276     07 TO 09           146.0        Maisonette                 1987
# 919277     04 TO 06           164.0  Multi Generation                 1987
#
#         resale_price
# 0             9000.0
# 1             6000.0
# 2             8000.0
# 3             6000.0
# 4            47200.0
# ...              ...
# 919273      860000.0
# 919274      820000.0
# 919275      795000.0
# 919276      935000.0
# 919277      998000.0
#
# [919278 rows x 10 columns]

# %%
#Distribution of resale
snb.histplot(df['resale_price'], bins = 20, color='Green')
plt.title('Distribution of resale price')
plt.show()

# %%
#Distribution of floor area
snb.histplot(df['floor_area_sqm'], bins = 20, color='Green')
plt.title('Distribution of Sqft')
plt.show()

# %%
#Distribution of flat
df['flat_type'].value_counts().plot(kind = 'bar',color='Green')
plt.show()

# %% [markdown]
# Dealing with Features

# %%
#Flat type
df['flat_type'].value_counts()
# Out:
# 4 ROOM              349015
# 3 ROOM              294005
# 5 ROOM              193631
# EXECUTIVE            69181
# 2 ROOM               11606
# 1 ROOM                1300
# MULTI GENERATION       279
# MULTI-GENERATION       261
# Name: flat_type, dtype: int64

# %%
# Unique lables in flat_type column
df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %% [markdown]
# Encoding the flat type

# %%
# Assigning the value-pairs to be replaced
cat = {'1 ROOM': 1,
       '2 ROOM':2,
       '3 ROOM':3,
       '4 ROOM':4,
       '5 ROOM':5,
       'EXECUTIVE':6,
       'MULTI GENERATION':7}

# %%
# Replacing the values in df
df['flat_type'] = df['flat_type'].replace(cat)
df['flat_type'].value_counts()
# Out:
# 4                   349015
# 3                   294005
# 5                   193631
# 6                    69181
# 2                    11606
# 1                     1300
# 7                      279
# MULTI-GENERATION       261
# Name: flat_type, dtype: int64

# %%
# Collapsing the flat_type categories
mapping={'MULTI-GENERATION':'MULTI GENERATION'}

df['flat_type'] = df['flat_type'].replace(mapping)
df['flat_type'].unique()
# Out:
# array([1, 3, 4, 5, 2, 6, 7, 'MULTI GENERATION'], dtype=object)

# %% [markdown]
# Dealing with flat type

# %%
# Flat_model column
print(df['flat_model'].nunique())
df['flat_model'].unique()
# Out:
# 34
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'DBSS', 'Type S1',
#        'Type S2', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
#changing into small letters
df['flat_model'] = df['flat_model'].str.lower()

# %%
#flat_model value counts
df['flat_model'].value_counts()
# Out:
# model a                   262013
# improved                  239947
# new generation            188056
# simplified                 57269
# premium apartment          46006
# standard                   42353
# apartment                  35235
# maisonette                 29481
# model a2                   10051
# dbss                        3231
# model a-maisonette          2065
# adjoined flat               1237
# terrace                      690
# multi generation             540
# type s1                      430
# type s2                      213
# improved-maisonette          125
# 2-room                       117
# premium apartment loft       107
# premium maisonette            86
# 3gen                          26
# Name: flat_model, dtype: int64

# %% [markdown]
# Encoding the flat model

# %%
ecode= preprocessing.LabelEncoder()

flat_modelcode= ecode.fit_transform(df['flat_model'])
df.insert(loc = 8,
          column = 'flat_modelcode',
          value = flat_modelcode)
df['flat_modelcode'].value_counts()
# Out:
# 8     262013
# 5     239947
# 12    188056
# 16     57269
# 13     46006
# 17     42353
# 3      35235
# 7      29481
# 10     10051
# 4       3231
# 9       2065
# 2       1237
# 18       690
# 11       540
# 19       430
# 20       213
# 6        125
# 0        117
# 14       107
# 15        86
# 1         26
# Name: flat_modelcode, dtype: int64

# %% [markdown]
# Town column

# %%
# Town column
df['town'].nunique()
# Out:
# 27

# %%
#checking value counts
df['town'].value_counts()
# Out:
# TAMPINES           79380
# YISHUN             69538
# BEDOK              66271
# JURONG WEST        66119
# WOODLANDS          64982
# ANG MO KIO         51795
# HOUGANG            50309
# BUKIT BATOK        43910
# CHOA CHU KANG      37931
# BUKIT MERAH        34053
# PASIR RIS          33039
# SENGKANG           31931
# TOA PAYOH          31329
# QUEENSTOWN         28580
# GEYLANG            28012
# CLEMENTI           27884
# BUKIT PANJANG      27463
# KALLANG/WHAMPOA    26934
# JURONG EAST        24609
# SERANGOON          22698
# BISHAN             21162
# PUNGGOL            20102
# SEMBAWANG          13591
# MARINE PARADE       8002
# CENTRAL AREA        7090
# BUKIT TIMAH         2500
# LIM CHU KANG          64
# Name: town, dtype: int64

# %%
# Creating a column with encoded value
town = ecode.fit_transform(df['town'])
df.insert(loc = 2,
          column = 'town_code',
          value = town)

# %%
# Encoded value count
df['town_code'].value_counts()
# Out:
# 23    79380
# 26    69538
# 1     66271
# 13    66119
# 25    64982
# 0     51795
# 11    50309
# 3     43910
# 8     37931
# 4     34053
# 17    33039
# 21    31931
# 24    31329
# 19    28580
# 10    28012
# 9     27884
# 5     27463
# 14    26934
# 12    24609
# 22    22698
# 2     21162
# 18    20102
# 20    13591
# 16     8002
# 7      7090
# 6      2500
# 15       64
# Name: town_code, dtype: int64

# %% [markdown]
# Spliting the columns

# %%
# Print header of column
df['storey_range'].head()
# Out:
# 0    10 TO 12
# 1    04 TO 06
# 2    10 TO 12
# 3    07 TO 09
# 4    04 TO 06
# Name: storey_range, dtype: object

# %%
# Splitting storey range column
storey=df['storey_range'].str.split(' TO ',expand = True)
storey.head()
# Out:
#     0   1
# 0  10  12
# 1  04  06
# 2  10  12
# 3  07  09
# 4  04  06

# %%
# Creating the storey minimum values as column
df.insert(loc = 6,
          column = 'storey_min',
          value = storey[0])
# Creating the storey maximum values as column
df.insert(loc = 7,
          column = 'storey_max',
          value = storey[1])

# %%
#Spliting the month columns
month=df['month'].str.split('-',expand = True)
month.head()
# Out:
#       0   1
# 0  1990  01
# 1  1990  01
# 2  1990  01
# 3  1990  01
# 4  1990  01

# %%
# Creating the year values as column
df.insert(loc = 1,
          column = 'selling_year',
          value = month[0])
# Creating the storey maximum values as column
df.insert(loc = 2,
          column = 'selling_month',
          value = month[1])

# %%
df = df[['selling_month', 'selling_year','town', 'town_code',	'flat_type',	'block',	'street_name',	'storey_min',
         'storey_max',	'storey_range',	'floor_area_sqm',	'flat_model',	'flat_modelcode',
         'lease_commence_date',	'resale_price' ]]

# %%
df.head()
# Out:
#   selling_month selling_year        town  town_code flat_type block  \
# 0            01         1990  ANG MO KIO          0         1   309
# 1            01         1990  ANG MO KIO          0         1   309
# 2            01         1990  ANG MO KIO          0         1   309
# 3            01         1990  ANG MO KIO          0         1   309
# 4            01         1990  ANG MO KIO          0         3   216
#
#         street_name storey_min storey_max storey_range  floor_area_sqm  \
# 0  ANG MO KIO AVE 1         10         12     10 TO 12            31.0
# 1  ANG MO KIO AVE 1         04         06     04 TO 06            31.0
# 2  ANG MO KIO AVE 1         10         12     10 TO 12            31.0
# 3  ANG MO KIO AVE 1         07         09     07 TO 09            31.0
# 4  ANG MO KIO AVE 1         04         06     04 TO 06            73.0
#
#        flat_model  flat_modelcode  lease_commence_date  resale_price
# 0        improved               5                 1977        9000.0
# 1        improved               5                 1977        6000.0
# 2        improved               5                 1977        8000.0
# 3        improved               5                 1977        6000.0
# 4  new generation              12                 1976       47200.0

# %% [markdown]
# Checking Datatypes

# %%
df.dtypes
# Out:
# selling_month           object
# selling_year            object
# town                    object
# town_code                int64
# flat_type               object
# block                   object
# street_name             object
# storey_min              object
# storey_max              object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# flat_modelcode           int64
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %%
#changing some dtype to numeric data
df_copy = df.copy()
df_copy.loc[:, 'selling_month'] = df_copy['selling_month'].astype(int)
df_copy.loc[:, 'selling_year'] = df_copy['selling_year'].astype(int)
df_copy.loc[:, 'storey_min'] = df_copy['storey_min'].astype(int)
df_copy.loc[:, 'storey_max'] = df_copy['storey_max'].astype(int)

# %%
df.dtypes
# Out:
# selling_month            int64
# selling_year             int64
# town                    object
# town_code                int64
# flat_type               object
# block                   object
# street_name             object
# storey_min               int64
# storey_max               int64
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# flat_modelcode           int64
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %% [markdown]
# Correlation Check

# %%
corr_df = df[['selling_month', 'selling_year', 'town_code', 'storey_min', 'storey_max',
              'floor_area_sqm', 'flat_modelcode', 'lease_commence_date', 'resale_price']].dropna().corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
snb.heatmap(corr_df,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
#downloading cleaned datasets
df.to_csv('final.csv',index=False)
