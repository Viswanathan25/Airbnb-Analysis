# %%
import pandas as pd
import pymongo 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#connecting mongo_DB 
viswa = pymongo.MongoClient("Enter_your_id")

# %%
db = viswa["sample_airbnb"]
col = db["listingsAndReviews"]

# %%
pd.set_option('display.max_columns', None)

# %%
Data = []

for i in col.find( {}, {'id':1, 'listing_url':1, 'name':1, 'description':1, 'house_rules':1, 'property_type':1, 'room_type':1,
                        'bed_type':1, 'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1, 
                        'bedrooms':1, 'beds':1, 'price':1, 'security_deposit':1, 'cleaning_fee':1, 
                        'extra_people':1, 'guests_included':1, 'number_of_reviews':1,'review_scores.review_scores_rating':1,
                        'bathrooms':1, 'amenities':1} ):
    Data.append(i)

# %%
df = pd.DataFrame(Data)
df['review_scores'] = df['review_scores'].apply(lambda x: x.get('review_scores_rating',0))
df
# Out:
#            _id                            listing_url  \
# 0     10057447  https://www.airbnb.com/rooms/10057447
# 1      1003530   https://www.airbnb.com/rooms/1003530
# 2     10069642  https://www.airbnb.com/rooms/10069642
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10138784  https://www.airbnb.com/rooms/10138784
# ...        ...                                    ...
# 5550   9696653   https://www.airbnb.com/rooms/9696653
# 5551   9834713   https://www.airbnb.com/rooms/9834713
# 5552   9721256   https://www.airbnb.com/rooms/9721256
# 5553   9762946   https://www.airbnb.com/rooms/9762946
# 5554   9867316   https://www.airbnb.com/rooms/9867316
#
#                                                name  \
# 0                    Modern Spacious 1 Bedroom Loft
# 1               New York City - Upper West Side Apt
# 2                Ótimo Apto proximo Parque Olimpico
# 3                 City center private room with bed
# 4     Room Close to LGA and 35 mins to Times Square
# ...                                             ...
# 5550                   Stylish 1br apt west village
# 5551                                    旺角地铁站附近三房一厅
# 5552                     Dover 42, Friendly Rentals
# 5553                                          干淨,整潔
# 5554     Beautiful Place in the Middle of Manhattan
#
#                                             description  \
# 0     Prime location, amazing lighting and no annoyi...
# 1     Murphy bed, optional second bedroom available....
# 2     Apartamento próximo ao centro dos Jogos Olímpi...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     A private small bedroom in a 2 BR 1BA apartmen...
# ...                                                 ...
# 5550  Make yourself at home - amazing locations in t...
# 5551                                      交通方便,购物旅遊好去處_
# 5552  This apartment has: 4 single beds, 1 double so...
# 5553                             環境清淨,交通便利,近郊區.接觸香港大自然.
# 5554  Beautiful place only a couple blocks from main...
#
#                                             house_rules property_type  \
# 0                                                           Apartment
# 1     No smoking is permitted in the apartment. All ...     Apartment
# 2                                                           Apartment
# 3     1. 禁止吸煙, 只限女生入住 (除得到批准) No smoking and only fe...    Guesthouse
# 4     * check-in time AFTER 5:00 pm. Guest is requir...     Apartment
# ...                                                 ...           ...
# 5550                                                        Apartment
# 5551                                                        Apartment
# 5552  CHECK-IN Week Days: The check-in and key colle...     Apartment
# 5553                                                            House
# 5554  1. NO smoking 2. NO outside guests 3. Please t...     Apartment
#
#             room_type  bed_type minimum_nights maximum_nights  \
# 0     Entire home/apt  Real Bed              1           1125
# 1        Private room  Real Bed             12            360
# 2     Entire home/apt  Real Bed             15             20
# 3        Private room     Futon              1            500
# 4        Private room  Real Bed              2           1125
# ...               ...       ...            ...            ...
# 5550  Entire home/apt  Real Bed              1           1125
# 5551  Entire home/apt  Real Bed              1           1125
# 5552  Entire home/apt  Real Bed              1             27
# 5553     Private room  Real Bed              1           1125
# 5554  Entire home/apt  Real Bed              1           1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0                        flexible             4       1.0   2.0
# 1     strict_14_with_grace_period             2       1.0   1.0
# 2     strict_14_with_grace_period             5       2.0   2.0
# 3     strict_14_with_grace_period             1       1.0   1.0
# 4     strict_14_with_grace_period             2       1.0   1.0
# ...                           ...           ...       ...   ...
# 5550  strict_14_with_grace_period             2       1.0   1.0
# 5551  strict_14_with_grace_period             8       3.0   8.0
# 5552  strict_14_with_grace_period             5       2.0   4.0
# 5553                     flexible             1       1.0   1.0
# 5554  strict_14_with_grace_period             2       1.0   1.0
#
#       number_of_reviews bathrooms  \
# 0                     0       1.0
# 1                    70       1.0
# 2                     0       2.0
# 3                    81       1.0
# 4                   123       1.0
# ...                 ...       ...
# 5550                108       1.0
# 5551                  5       2.0
# 5552                 12       1.0
# 5553                  2       1.0
# 5554                180       1.0
#
#                                               amenities    price extra_people  \
# 0     [Internet, Wifi, Kitchen, Heating, Family/kid ...    50.00        31.00
# 1     [Internet, Wifi, Air conditioning, Kitchen, El...   135.00         0.00
# 2     [TV, Cable TV, Internet, Wifi, Air conditionin...   858.00        75.00
# 3     [TV, Wifi, Air conditioning, Kitchen, Elevator...   181.00       100.00
# 4     [Internet, Wifi, Air conditioning, Pets live o...    46.00        10.00
# ...                                                 ...      ...          ...
# 5550  [Wifi, Air conditioning, Kitchen, Heating, Smo...   108.00         0.00
# 5551  [TV, Wifi, Air conditioning, Smoking allowed, ...  1162.00       100.00
# 5552  [TV, Wifi, Air conditioning, Kitchen, Elevator...    62.00         0.00
# 5553  [TV, Wifi, Air conditioning, Elevator, Hot tub...   196.00         0.00
# 5554  [Wifi, Air conditioning, Kitchen, Pets allowed...   160.00        20.00
#
#      guests_included  review_scores security_deposit cleaning_fee
# 0                  1              0              NaN          NaN
# 1                  1             94             0.00       135.00
# 2                  1              0          4476.00       112.00
# 3                  1             92             0.00        50.00
# 4                  1             99             0.00        15.00
# ...              ...            ...              ...          ...
# 5550               1             92              NaN        80.00
# 5551               1             60              NaN          NaN
# 5552               5             85           200.00        85.00
# 5553               1             60              NaN          NaN
# 5554               2             92           250.00        40.00
#
# [5555 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# description               0
# house_rules               0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# amenities                 0
# price                     0
# extra_people              0
# guests_included           0
# review_scores             0
# security_deposit       2084
# cleaning_fee           1531
# dtype: int64

# %%
#Filling the missing value
df['bedrooms'].fillna(0,inplace=True)
df['beds'].fillna(0,inplace=True)
df['bathrooms'].fillna(0,inplace=True)
df['cleaning_fee'].fillna(0,inplace=True)
df['security_deposit'].fillna(0,inplace=True)

# Filling Empty values in Description and House rules columns
df.description.replace(to_replace='',value='No Description Provided',inplace=True)
df.house_rules.replace(to_replace='',value='No House rules Provided',inplace=True)
df.amenities.replace(to_replace='',value='Not Available',inplace=True)
df.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# description            0
# house_rules            0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# amenities              0
# price                  0
# extra_people           0
# guests_included        0
# review_scores          0
# security_deposit       0
# cleaning_fee           0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# _id                     0
# listing_url             0
# name                    0
# property_type           0
# room_type               0
# bed_type                0
# minimum_nights          0
# maximum_nights          0
# accommodates            0
# bedrooms                5
# beds                   13
# number_of_reviews       0
# bathrooms              10
# price                   0
# extra_people            0
# guests_included         0
# images                  0
# review_scores           0
# cleaning_fee         1531
# dtype: int64

# %%
#checking data types
df.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# description             object
# house_rules             object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# amenities               object
# price                   object
# extra_people            object
# guests_included         object
# review_scores            int64
# security_deposit        object
# cleaning_fee            object
# dtype: object

# %%
df['minimum_nights'] = df['minimum_nights'].astype(int)
df['maximum_nights'] = df['maximum_nights'].astype(int)
df['beds'] = df['beds'].astype(int)
df['bathrooms'] = df['bathrooms'].astype(str).astype(float)
df['price'] = df['price'].astype(str).astype(float).astype(int)
df['extra_people'] = df['extra_people'].astype(str).astype(float).astype(int)
df['guests_included'] = df['guests_included'].astype(str).astype(int)
df['cleaning_fee'] = df['cleaning_fee'].astype(str).astype(float).astype(int)
df['security_deposit'] = df['security_deposit'].astype(str).astype(float)

# %%
df.head(3)
# Out:
#         _id                            listing_url  \
# 0  10057447  https://www.airbnb.com/rooms/10057447
# 1   1003530   https://www.airbnb.com/rooms/1003530
# 2  10069642  https://www.airbnb.com/rooms/10069642
#
#                                   name  \
# 0       Modern Spacious 1 Bedroom Loft
# 1  New York City - Upper West Side Apt
# 2   Ótimo Apto proximo Parque Olimpico
#
#                                          description  \
# 0  Prime location, amazing lighting and no annoyi...
# 1  Murphy bed, optional second bedroom available....
# 2  Apartamento próximo ao centro dos Jogos Olímpi...
#
#                                          house_rules property_type  \
# 0                            No House rules Provided     Apartment
# 1  No smoking is permitted in the apartment. All ...     Apartment
# 2                            No House rules Provided     Apartment
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               1            1125
# 1     Private room  Real Bed              12             360
# 2  Entire home/apt  Real Bed              15              20
#
#            cancellation_policy  accommodates  bedrooms  beds  \
# 0                     flexible             4       1.0     2
# 1  strict_14_with_grace_period             2       1.0     1
# 2  strict_14_with_grace_period             5       2.0     2
#
#    number_of_reviews  bathrooms  \
# 0                  0        1.0
# 1                 70        1.0
# 2                  0        2.0
#
#                                            amenities  price  extra_people  \
# 0  [Internet, Wifi, Kitchen, Heating, Family/kid ...     50            31
# 1  [Internet, Wifi, Air conditioning, Kitchen, El...    135             0
# 2  [TV, Cable TV, Internet, Wifi, Air conditionin...    858            75
#
#    guests_included  review_scores  security_deposit  cleaning_fee
# 0                1              0               0.0             0
# 1                1             94               0.0           135
# 2                1              0            4476.0           112

# %%
# host
host = []

for i in col.find( {}, {'id':1, 'host':1}):
    host.append(i)

df_host = pd.DataFrame(host)
host_keys = list(df_host.iloc[0,1].keys())
host_keys.remove('host_about')


for i in host_keys:
    if i == 'host_response_time':
        df_host['host_response_time'] = df_host['host'].apply(lambda x: x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df_host[i] = df_host['host'].apply(lambda x: x[i] if i in x and x[i]!='' else 'Not Specified')

df_host.drop(columns=['host'], inplace=True)
df_host.head()
# Out:
#         _id   host_id                                    host_url   host_name  \
# 0  10057447  51612949  https://www.airbnb.com/users/show/51612949  Konstantin
# 1   1003530    454250    https://www.airbnb.com/users/show/454250       Greta
# 2  10069642  51670240  https://www.airbnb.com/users/show/51670240    Jonathan
# 3  10084023  51744313  https://www.airbnb.com/users/show/51744313          Yi
# 4  10138784  52031360  https://www.airbnb.com/users/show/52031360       Cheer
#
#                        host_location  \
# 0           Montreal, Quebec, Canada
# 1  New York, New York, United States
# 2    Resende, Rio de Janeiro, Brazil
# 3                      United States
# 4  New York, New York, United States
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...
# 2  https://a0.muscache.com/im/pictures/9a6839d9-9...
# 3  https://a0.muscache.com/im/pictures/user/a204d...
# 4  https://a0.muscache.com/im/pictures/1e61ad3c-e...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 2  https://a0.muscache.com/im/pictures/9a6839d9-9...      Not Specified
# 3  https://a0.muscache.com/im/pictures/user/a204d...       Shek Kip Mei
# 4  https://a0.muscache.com/im/pictures/1e61ad3c-e...    Jackson Heights
#
#    host_is_superhost  host_has_profile_pic  host_identity_verified  \
# 0              False                  True                   False
# 1               True                  True                    True
# 2              False                  True                   False
# 3              False                  True                    True
# 4               True                  True                    True
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    3                          3
# 2                    1                          1
# 3                    2                          2
# 4                    1                          1
#
#                                   host_verifications
# 0  [email, phone, jumio, offline_government_id, s...
# 1  [email, phone, reviews, jumio, offline_governm...
# 2               [email, phone, jumio, government_id]
# 3  [email, phone, reviews, jumio, offline_governm...
# 4  [email, phone, reviews, jumio, offline_governm...

# %%
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({False:'No',True:'Yes'})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({False:'No',True:'Yes'})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({False:'No',True:'Yes'})
df_host.head(1)
# Out:
#         _id   host_id                                    host_url   host_name  \
# 0  10057447  51612949  https://www.airbnb.com/users/show/51612949  Konstantin
#
#               host_location  \
# 0  Montreal, Quebec, Canada
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/beb6b50e-0...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
#
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                No                  Yes                     No
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
#
#                                   host_verifications
# 0  [email, phone, jumio, offline_government_id, s...

# %%
df_host.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
#address

add = []
for i in col.find( {}, {'id':1, 'address':1}):
    add.append(i)
    
df_add = pd.DataFrame(add)
address_keys = list(df_add.iloc[0,1].keys())

for i in address_keys:
    if i == 'location':
        df_add['location__type'] = df_add['address'].apply(lambda x: x['location']['type'])
        df_add['longitude'] = df_add['address'].apply(lambda x: x['location']['coordinates'][0])
        df_add['latitude'] = df_add['address'].apply(lambda x: x['location']['coordinates'][1])
        df_add['is_location_exact'] = df_add['address'].apply(lambda x: x['location']['is_location_exact'])
    else:   
        df_add[i] = df_add['address'].apply(lambda x: x[i] if x[i]!='' else 'Not specified')
df_add.drop(columns=['address'], inplace=True)
df_add.head(3)
# Out:
#         _id                                  street                    suburb  \
# 0  10057447                Montréal, Québec, Canada                  Mile End
# 1   1003530             New York, NY, United States                 Manhattan
# 2  10069642  Rio de Janeiro, Rio de Janeiro, Brazil  Recreio dos Bandeirantes
#
#             government_area          market        country country_code  \
# 0     Le Plateau-Mont-Royal        Montreal         Canada           CA
# 1           Upper West Side        New York  United States           US
# 2  Recreio dos Bandeirantes  Rio De Janeiro         Brazil           BR
#
#   location__type  longitude   latitude  is_location_exact
# 0          Point -73.591110  45.518890               True
# 1          Point -73.965230  40.799620              False
# 2          Point -43.431112 -23.000358              False

# %%
df_add['is_location_exact'] = df_add['is_location_exact'].map({False:'No',True:'Yes'})
df_add.head(3)
# Out:
#         _id                                  street                    suburb  \
# 0  10057447                Montréal, Québec, Canada                  Mile End
# 1   1003530             New York, NY, United States                 Manhattan
# 2  10069642  Rio de Janeiro, Rio de Janeiro, Brazil  Recreio dos Bandeirantes
#
#             government_area          market        country country_code  \
# 0     Le Plateau-Mont-Royal        Montreal         Canada           CA
# 1           Upper West Side        New York  United States           US
# 2  Recreio dos Bandeirantes  Rio De Janeiro         Brazil           BR
#
#   location__type  longitude   latitude is_location_exact
# 0          Point -73.591110  45.518890               Yes
# 1          Point -73.965230  40.799620                No
# 2          Point -43.431112 -23.000358                No

# %%
df_add.isnull().sum(),df_add.dtypes
# Out:
# (_id                  0
#  street               0
#  suburb               0
#  government_area      0
#  market               0
#  country              0
#  country_code         0
#  location__type       0
#  longitude            0
#  latitude             0
#  is_location_exact    0
#  dtype: int64,
#  _id                   object
#  street                object
#  suburb                object
#  government_area       object
#  market                object
#  country               object
#  country_code          object
#  location__type        object
#  longitude            float64
#  latitude             float64
#  is_location_exact     object
#  dtype: object)

# %%
#Availablity
availability = []
for i in col.find( {}, {'_id':1, 'availability':1}):
    availability.append(i)

df_availability = pd.DataFrame(availability)
availability_keys = list(df_availability.iloc[0,1].keys())

for i in availability_keys:
    df_availability['availability_30'] = df_availability['availability'].apply(lambda x: x['availability_30'])
    df_availability['availability_60'] = df_availability['availability'].apply(lambda x: x['availability_60'])
    df_availability['availability_90'] = df_availability['availability'].apply(lambda x: x['availability_90'])
    df_availability['availability_365'] = df_availability['availability'].apply(lambda x: x['availability_365'])

df_availability.drop(columns=['availability'], inplace=True)
df_availability.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0  10057447                0                0                0
# 1   1003530                0                0                0
# 2  10069642                0                0                0
# 3  10084023               14               24               40
# 4  10138784               30               60               90
#
#    availability_365
# 0                 0
# 1                93
# 2                 0
# 3               220
# 4               365

# %%
df_availability.isnull().sum(),df_availability.dtypes
# Out:
# (_id                 0
#  availability_30     0
#  availability_60     0
#  availability_90     0
#  availability_365    0
#  dtype: int64,
#  _id                 object
#  availability_30      int64
#  availability_60      int64
#  availability_90      int64
#  availability_365     int64
#  dtype: object)

# %%
df = pd.merge(df, df_host, on='_id')
df = pd.merge(df, df_add, on='_id')
df = pd.merge(df, df_availability, on='_id')

# %%
df.head(2)
# Out:
#         _id                            listing_url  \
# 0  10057447  https://www.airbnb.com/rooms/10057447
# 1   1003530   https://www.airbnb.com/rooms/1003530
#
#                                   name  \
# 0       Modern Spacious 1 Bedroom Loft
# 1  New York City - Upper West Side Apt
#
#                                          description  \
# 0  Prime location, amazing lighting and no annoyi...
# 1  Murphy bed, optional second bedroom available....
#
#                                          house_rules property_type  \
# 0                            No House rules Provided     Apartment
# 1  No smoking is permitted in the apartment. All ...     Apartment
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               1            1125
# 1     Private room  Real Bed              12             360
#
#            cancellation_policy  accommodates  bedrooms  beds  \
# 0                     flexible             4       1.0     2
# 1  strict_14_with_grace_period             2       1.0     1
#
#    number_of_reviews  bathrooms  \
# 0                  0        1.0
# 1                 70        1.0
#
#                                            amenities  price  extra_people  \
# 0  [Internet, Wifi, Kitchen, Heating, Family/kid ...     50            31
# 1  [Internet, Wifi, Air conditioning, Kitchen, El...    135             0
#
#    guests_included  review_scores  security_deposit  cleaning_fee   host_id  \
# 0                1              0               0.0             0  51612949
# 1                1             94               0.0           135    454250
#
#                                      host_url   host_name  \
# 0  https://www.airbnb.com/users/show/51612949  Konstantin
# 1    https://www.airbnb.com/users/show/454250       Greta
#
#                        host_location  \
# 0           Montreal, Quebec, Canada
# 1  New York, New York, United States
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
#
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                No                  Yes                     No
# 1               Yes                  Yes                    Yes
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    3                          3
#
#                                   host_verifications  \
# 0  [email, phone, jumio, offline_government_id, s...
# 1  [email, phone, reviews, jumio, offline_governm...
#
#                         street     suburb        government_area    market  \
# 0     Montréal, Québec, Canada   Mile End  Le Plateau-Mont-Royal  Montreal
# 1  New York, NY, United States  Manhattan        Upper West Side  New York
#
#          country country_code location__type  longitude  latitude  \
# 0         Canada           CA          Point  -73.59111  45.51889
# 1  United States           US          Point  -73.96523  40.79962
#
#   is_location_exact  availability_30  availability_60  availability_90  \
# 0               Yes                0                0                0
# 1                No                0                0                0
#
#    availability_365
# 0                 0
# 1                93

# %%
df.dtypes
# Out:
# _id                           object
# listing_url                   object
# name                          object
# description                   object
# house_rules                   object
# property_type                 object
# room_type                     object
# bed_type                      object
# minimum_nights                 int32
# maximum_nights                 int32
# cancellation_policy           object
# accommodates                   int64
# bedrooms                     float64
# beds                           int32
# number_of_reviews              int64
# bathrooms                    float64
# amenities                     object
# price                          int32
# extra_people                   int32
# guests_included                int32
# review_scores                  int64
# security_deposit             float64
# cleaning_fee                   int32
# host_id                       object
# host_url                      object
# host_name                     object
# host_location                 object
# host_thumbnail_url            object
# host_picture_url              object
# host_neighbourhood            object
# host_is_superhost             object
# host_has_profile_pic          object
# host_identity_verified        object
# host_listings_count            int64
# host_total_listings_count      int64
# host_verifications            object
# street                        object
# suburb                        object
# government_area               object
# market                        object
# country                       object
# country_code                  object
# location__type                object
# longitude                    float64
# latitude                     float64
# is_location_exact             object
# availability_30                int64
# availability_60                int64
# availability_90                int64
# availability_365               int64
# dtype: object

# %%
#Converting dataframe to csv file and saving it
df.to_csv('Airbnb_data.csv',index=False)
